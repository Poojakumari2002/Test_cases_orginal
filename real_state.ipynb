# %%
import pandas as pd
x= pd.read_csv("C:/Users/admin/Downloads/12.real state.csv")
x
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA     2      1     796
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA     2      1     797
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   street     985 non-null    object
#  1   city       985 non-null    object
#  2   zip        985 non-null    int64
#  3   state      985 non-null    object
#  4   beds       985 non-null    int64
#  5   baths      985 non-null    int64
#  6   sq__ft     985 non-null    int64
#  7   type       985 non-null    object
#  8   sale_date  985 non-null    object
#  9   price      985 non-null    int64
#  10  latitude   985 non-null    float64
#  11  longitude  985 non-null    float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.5+ KB

# %%
#city wise list of villa which is less than 10000
city = x[(x['type'] == 'villa') & (x['price']>=10000)]
print(city[['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
            'sale_date', 'price', 'latitude', 'longitude']])
print= x.head(5)
# Out:
#                                   street            city    zip state  beds  \
# 5                     5828 PEPPERMILL CT      SACRAMENTO  95841    CA     3
# 8        11150 TRINITY RIVER DR Unit 114  RANCHO CORDOVA  95670    CA     2
# 15                        7340 HAMDEN PL      SACRAMENTO  95842    CA     2
# 17               6236 LONGFORD DR Unit 1  CITRUS HEIGHTS  95621    CA     2
# 30          5201 LAGUNA OAKS DR Unit 140       ELK GROVE  95758    CA     2
# 34          5201 LAGUNA OAKS DR Unit 162       ELK GROVE  95758    CA     2
# 39                      2442 LARKSPUR LN      SACRAMENTO  95825    CA     1
# 40          4800 WESTLAKE PKWY Unit 2109      SACRAMENTO  95835    CA     2
# 94                          4010 ALEX LN      CARMICHAEL  95608    CA     2
# 101              4236 NATOMAS CENTRAL DR      SACRAMENTO  95834    CA     3
# 158              6272 LONGFORD DR Unit 1  CITRUS HEIGHTS  95621    CA     2
# ...

# %%
#residentail type less than 800 sq__ft in city= 'Galt'
Galt_residential= x[(x['city']== 'GALT') & (x['type']== 'Residential') & (x['sq__ft'] > 800)]
print(Galt_residential[['street', 'sq__ft', 'sale_date', 'city']])
# Out:
#                   street  sq__ft                     sale_date  city
# 55    1122 WILD POPPY CT    1406  Wed May 21 00:00:00 EDT 2008  GALT
# 61      306 CAMELLIA WAY    1130  Wed May 21 00:00:00 EDT 2008  GALT
# 63            404 6TH ST    1479  Wed May 21 00:00:00 EDT 2008  GALT
# 174   1121 CREEKSIDE WAY    1080  Tue May 20 00:00:00 EDT 2008  GALT
# 189      840 TRANQUIL LN    1266  Tue May 20 00:00:00 EDT 2008  GALT
# 281        993 MANTON CT    2307  Tue May 20 00:00:00 EDT 2008  GALT
# 296    796 BUTTERCUP CIR    2159  Tue May 20 00:00:00 EDT 2008  GALT
# 307      1092 MAUGHAM CT    3746  Tue May 20 00:00:00 EDT 2008  GALT
# 372         201 CARLO CT    1080  Mon May 19 00:00:00 EDT 2008  GALT
# 402  746 MOOSE CREEK WAY    1100  Mon May 19 00:00:00 EDT 2008  GALT
# 409        332 PALIN AVE    1204  Mon May 19 00:00:00 EDT 2008  GALT
# 439        913 COBDEN CT    1555  Mon May 19 00:00:00 EDT 2008  GALT
# 454      709 CIMMARON CT    1798  Mon May 19 00:00:00 EDT 2008  GALT
# ...

# %%
x.columns
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %%
#top 5 residency details which lie in the budget of 60000-120000, an area more than 1450, min bedroom 3 and, min bathroom 2.
x=x.copy()
x['price']= x['price'].between(60000,120000,inclusive=True)
x['sq__ft']=x['sq__ft'] >1450
x['beds']= x['beds'] >2
x['baths']= x['baths'] >1
x
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_3924\490767827.py:2: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   x['price']= x['price'].between(60000,120000,inclusive=True)
#                   street             city    zip state   beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA  False  False   False
# 1            51 OMAHA CT       SACRAMENTO  95823    CA  False  False   False
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA  False  False   False
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA  False  False   False
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA  False  False   False
# ..                   ...              ...    ...   ...    ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA  False  False   False
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA  False  False   False
# ...

# %%
#separate list of residential apartments with more than 2 beds with particular columns
resi= x[(x['type'] == 'Residential') & (x['beds'] > 2)]
result= resi[['city', 'baths', 'sq__ft', 'beds', 'price', 'type']]
print(result)
# Out:
#                 city  baths  sq__ft  beds   price         type
# 1         SACRAMENTO      1    1167     3   68212  Residential
# 6         SACRAMENTO      2    1104     3   90895  Residential
# 7         SACRAMENTO      1    1177     3   91002  Residential
# 9          RIO LINDA      2    1146     3   98937  Residential
# 10        SACRAMENTO      2     909     3  100309  Residential
# ..               ...    ...     ...   ...     ...          ...
# 980       SACRAMENTO      3    2280     4  232425  Residential
# 981       SACRAMENTO      2    1477     3  234000  Residential
# 982   CITRUS HEIGHTS      2    1216     3  235000  Residential
# 983        ELK GROVE      2    1685     4  235301  Residential
# 984  EL DORADO HILLS      2    1362     3  235738  Residential
#
# [715 rows x 6 columns]

# %%
#chepeast villa in california.
ca_villa= x[(x['state'] == 'CA') & (x['type']=='villa')]
cheapest_property= ca_villa.loc[ca_villa['price'].idxmin()]
print('the cheapest villa property in California is located at', cheapest_property['street'],',',cheapest_property['city'], ',', cheapest_property ['price'])
# Out:
# the cheapest villa property in California is located at 5840 WALERGA RD , SACRAMENTO , 40000

# %%
residential = x[(x['typ'] > 60000) & (x['price'] < 120000) & (x['sq__ft'] > 1450) & (x['beds'] >= 3) & (x['baths'] >= 2) & (x['type'] == 'residential')]

# Print the first 5 rows of the filtered DataFrame
print(residential.head(5))
# Out:
# Empty DataFrame
# Columns: [street, city, zip, state, beds, baths, sq__ft, type, sale_date, price, latitude, longitude]
# Index: []
